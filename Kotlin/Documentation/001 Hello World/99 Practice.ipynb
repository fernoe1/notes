// %% [markdown]
// # Exercises
// ### Exercise one
// Print out Mary is 20 years old using template expressions.

// %% [markdown]
// # Solutions

// %%
val name = "Mary"
val age = 20
"$name is $age years old"
// Out:
// Mary is 20 years old
